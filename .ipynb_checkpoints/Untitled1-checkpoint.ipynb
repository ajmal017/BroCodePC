# %%
import IB_API_tutorial as ib
import datetime

port = 7496
ip = "127.0.0.1"
clientID = 1

# %%
app.disconnect()
from importlib import reload
reload (ib)
# Out:
# <module 'IB_API_tutorial' from '/Users/chingaling/Documents/Algo Trading/BroCodePC/IB_API_tutorial.py'>

# %%
# Test connection
clientID = 2
app = ib.TestApp(ip, port, clientID)
current_time = app.speaking_clock()
print(current_time)
# Out:
# Getting the time from the server...
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm.nj
# IB error id -1 errorcode 2104 string Market data farm connection is OK:usfuture
# IB error id -1 errorcode 2104 string Market data farm connection is OK:eufarm
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds.us
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ilhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:hkhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:fundfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds
# 1543329414

# %%
app.main_trading()
# Out:
# IB error id -1 errorcode 504 string Not connected
# IB error id -1 errorcode 504 string Not connected
# Exceeded maximum wait for wrapper to confirm finished whilst getting orders
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm.nj
# IB error id -1 errorcode 2104 string Market data farm connection is OK:usfuture
# IB error id -1 errorcode 2104 string Market data farm connection is OK:eufarm
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds.us
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ilhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:hkhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:fundfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds
# Considering placing sell order for ATOM
# Position held for less than 2 days. Skipping
# Considering placing sell order for IMH
# Position held for less than 2 days. Skipping
# Considering placing sell order for ROSE
# Existing sell order in place. Skipping
# Considering placing sell order for BSGM
# Position held for less than 2 days. Skipping
# Considering placing sell order for STRO
# Position held for less than 2 days. Skipping
# Considering placing sell order for MBIO
# Position held for less than 2 days. Skipping
# Considering placing sell order for MGEN
# Position held for less than 2 days. Skipping
# Considering placing sell order for UROV
# Position held for less than 2 days. Skipping
# Considering placing sell order for MGTA
# Position held for less than 2 days. Skipping
# Considering placing sell order for CUE
# Position held for less than 2 days. Skipping
# Considering placing sell order for USD
# USD is a cash position. Not for sale
# Considering placing sell order for ASPN
# Position held for less than 2 days. Skipping
# Considering placing sell order for BTAI
# Existing sell order in place. Skipping
# Considering placing sell order for AEYE
# Do not have a position. Skipping
# Considering placing sell order for FTNW
# Existing sell order in place. Skipping
# Considering placing sell order for RKDA
# Existing sell order in place. Skipping
# Considering placing sell order for CERC
# Existing sell order in place. Skipping
# Considering placing sell order for SBT
# Position held for less than 2 days. Skipping
# Considering placing sell order for KEG
# Position held for less than 2 days. Skipping
# Considering placing sell order for SIC
# Existing sell order in place. Skipping
# Considering placing sell order for ICD
# Do not have a position. Skipping
# Considering placing sell order for ETTX
# Position held for less than 2 days. Skipping
# Considering placing sell order for RMED
# Position held for less than 2 days. Skipping
# Considering placing sell order for CRVS
# Position held for less than 2 days. Skipping
# 0	Buying_power: 100000
# Considering trading this stock: MBIO
# Wont trade this MBIO
# In positions?: True	In open_orders?: False	Traded today?: True
# 1	Buying_power: 100000
# Considering trading this stock: SPRO
# Getting full contract details from the server...
# got multiple contracts using first one
# 294729611,SPRO,STK,,0.0,,,SMART,NASDAQ,USD,SPRO,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 7.83
# Buying SPRO, 	shares: 129, 	price: 7.75
# Using order id of 197
# Placed order, orderid is 197
# 2	Buying_power: 100000
# Considering trading this stock: BXG
# Getting full contract details from the server...
# got multiple contracts using first one
# 296320248,BXG,STK,,0.0,,,SMART,NYSE,USD,BXG,BXG,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 12.37
# Buying BXG, 	shares: 81, 	price: 12.2
# Using order id of 198
# Placed order, orderid is 198
# 3	Buying_power: 100000
# Considering trading this stock: SBT
# Wont trade this SBT
# In positions?: True	In open_orders?: False	Traded today?: True
# 4	Buying_power: 100000
# Considering trading this stock: FTNW
# Wont trade this FTNW
# In positions?: True	In open_orders?: False	Traded today?: False
# 5	Buying_power: 100000
# Considering trading this stock: CUE
# Wont trade this CUE
# In positions?: True	In open_orders?: False	Traded today?: True
# 6	Buying_power: 100000
# Considering trading this stock: MOTS
# Getting full contract details from the server...
# got multiple contracts using first one
# 306363711,MOTS,STK,,0.0,,,SMART,NASDAQ,USD,MOTS,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 3.25
# Buying MOTS, 	shares: 312, 	price: 3.2
# Using order id of 199
# Placed order, orderid is 199
# 7	Buying_power: 100000
# Considering trading this stock: BTAI
# Wont trade this BTAI
# In positions?: True	In open_orders?: False	Traded today?: False
# 8	Buying_power: 100000
# Considering trading this stock: LAZY
# Getting full contract details from the server...
# got multiple contracts using first one
# 310624804,LAZY,STK,,0.0,,,SMART,NASDAQ,USD,LAZY,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: LAZY@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 9	Buying_power: 100000
# Considering trading this stock: CLPS
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Getting full contract details from the server...
# got multiple contracts using first one
# 319099408,CLPS,STK,,0.0,,,SMART,NASDAQ,USD,CLPS,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: CLPS@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 10	Buying_power: 100000
# Considering trading this stock: VRCA
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Getting full contract details from the server...
# got multiple contracts using first one
# 321419016,VRCA,STK,,0.0,,,SMART,NASDAQ,USD,VRCA,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: VRCA@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 11	Buying_power: 100000
# Considering trading this stock: NTGN
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Getting full contract details from the server...
# got multiple contracts using first one
# 323805491,NTGN,STK,,0.0,,,SMART,NASDAQ,USD,NTGN,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 6.25
# Buying NTGN, 	shares: 162, 	price: 6.15
# Using order id of 200
# Placed order, orderid is 200
# 12	Buying_power: 100000
# Considering trading this stock: MYFW
# Getting full contract details from the server...
# got multiple contracts using first one
# 326196504,MYFW,STK,,0.0,,,SMART,NASDAQ,USD,MYFW,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: MYFW@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 13	Buying_power: 100000
# Considering trading this stock: CHAP
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Getting full contract details from the server...
# got multiple contracts using first one
# 271664941,CHAP,STK,,0.0,,,SMART,NYSE,USD,CHAP,CHAP,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: CHAP@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 14	Buying_power: 100000
# Considering trading this stock: ETTX
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Wont trade this ETTX
# In positions?: True	In open_orders?: False	Traded today?: True
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm.nj
# IB error id -1 errorcode 2104 string Market data farm connection is OK:usfuture
# IB error id -1 errorcode 2104 string Market data farm connection is OK:eufarm
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds.us
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ilhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:hkhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:fundfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds
# Cancelling this order: avgFillPrice                                                                    0
# clientId                                                                        1
# filled                                                                          0
# id                                                                            198
# lastFillPrice                                                                   0
# mktCapPrice                                                                     0
# orderstate                      <ibapi.order_state.OrderState object at 0x1101...
# parentId                                                                        0
# permid                                                                 1574094659
# status                                                                  Submitted
# whyHeld
# comboLegs                                                                    None
# comboLegsCount                                                                  0
# comboLegsDescrip
# conId                                                                   296320248
# currency                                                                      USD
# deltaNeutralContract                                                         None
# deltaNeutralContractPresent                                                 False
# exchange                                                                    SMART
# includeExpired                                                              False
# lastTradeDateOrContractMonth
# localSymbol                                                                   BXG
# multiplier
# primaryExchange
# right                                                                           ?
# secId
# secIdType
# secType                                                                       STK
# strike                                                                          0
# symbol                                                                        BXG
#                                                       ...
# scalePriceAdjustInterval                                               2147483647
# scalePriceAdjustValue                                                1.79769e+308
# scalePriceIncrement                                                  1.79769e+308
# scaleProfitOffset                                                    1.79769e+308
# scaleRandomPercent                                                          False
# scaleSubsLevelSize                                                     2147483647
# scaleTable
# settlingFirm
# sharesAllocation                                        1574094659.0/U9509931/100
# shortSaleSlot                                                                   0
# smartComboRoutingParams                                                      None
# smartComboRoutingParamsCount                                                    0
# softDollarTier                                                                 =,
# solicited                                                                   False
# startingPrice                                                        1.79769e+308
# stockRangeLower                                                      1.79769e+308
# stockRangeUpper                                                      1.79769e+308
# stockRefPrice                                                        1.79769e+308
# sweepToFill                                                                 False
# tif                                                                           GTC
# totalQuantity                                                                  81
# trailStopPrice                                                               13.2
# trailingPercent                                                      1.79769e+308
# transmit                                                                     True
# triggerMethod                                                                   0
# triggerPrice                                                         1.79769e+308
# volatility                                                           1.79769e+308
# volatilityType                                                                  0
# whatIf                                                                      False
# time_added                                             2018-11-27 22:43:06.106672
# Name: 4, Length: 155, dtype: object
# 198
# IB error id 198 errorcode 202 string Order Canceled - reason:
# Cancelling this order: avgFillPrice                                                                    0
# clientId                                                                        1
# filled                                                                          0
# id                                                                            199
# lastFillPrice                                                                   0
# mktCapPrice                                                                     0
# orderstate                      <ibapi.order_state.OrderState object at 0x1101...
# parentId                                                                        0
# permid                                                                 1574095132
# status                                                                  Submitted
# whyHeld
# comboLegs                                                                    None
# comboLegsCount                                                                  0
# comboLegsDescrip
# conId                                                                   306363711
# currency                                                                      USD
# deltaNeutralContract                                                         None
# deltaNeutralContractPresent                                                 False
# exchange                                                                    SMART
# includeExpired                                                              False
# lastTradeDateOrContractMonth
# localSymbol                                                                  MOTS
# multiplier
# primaryExchange
# right                                                                           ?
# secId
# secIdType
# secType                                                                       STK
# strike                                                                          0
# symbol                                                                       MOTS
#                                                       ...
# scalePriceAdjustInterval                                               2147483647
# scalePriceAdjustValue                                                1.79769e+308
# scalePriceIncrement                                                  1.79769e+308
# scaleProfitOffset                                                    1.79769e+308
# scaleRandomPercent                                                          False
# scaleSubsLevelSize                                                     2147483647
# scaleTable
# settlingFirm
# sharesAllocation                                        1574095132.0/U9509931/100
# shortSaleSlot                                                                   0
# smartComboRoutingParams                                                      None
# smartComboRoutingParamsCount                                                    0
# softDollarTier                                                                 =,
# solicited                                                                   False
# startingPrice                                                        1.79769e+308
# stockRangeLower                                                      1.79769e+308
# stockRangeUpper                                                      1.79769e+308
# stockRefPrice                                                        1.79769e+308
# sweepToFill                                                                 False
# tif                                                                           GTC
# totalQuantity                                                                 312
# trailStopPrice                                                                4.2
# trailingPercent                                                      1.79769e+308
# transmit                                                                     True
# triggerMethod                                                                   0
# triggerPrice                                                         1.79769e+308
# volatility                                                           1.79769e+308
# volatilityType                                                                  0
# whatIf                                                                      False
# time_added                                             2018-11-27 22:43:21.098776
# Name: 5, Length: 155, dtype: object
# 199
# IB error id 199 errorcode 202 string Order Canceled - reason:
# Cancelling this order: avgFillPrice                                                                    0
# clientId                                                                        1
# filled                                                                          0
# id                                                                            200
# lastFillPrice                                                                   0
# mktCapPrice                                                                     0
# orderstate                      <ibapi.order_state.OrderState object at 0x1101...
# parentId                                                                        0
# permid                                                                 1574095737
# status                                                                  Submitted
# whyHeld
# comboLegs                                                                    None
# comboLegsCount                                                                  0
# comboLegsDescrip
# conId                                                                   323805491
# currency                                                                      USD
# deltaNeutralContract                                                         None
# deltaNeutralContractPresent                                                 False
# exchange                                                                    SMART
# includeExpired                                                              False
# lastTradeDateOrContractMonth
# localSymbol                                                                  NTGN
# multiplier
# primaryExchange
# right                                                                           ?
# secId
# secIdType
# secType                                                                       STK
# strike                                                                          0
# symbol                                                                       NTGN
#                                                       ...
# scalePriceAdjustInterval                                               2147483647
# scalePriceAdjustValue                                                1.79769e+308
# scalePriceIncrement                                                  1.79769e+308
# scaleProfitOffset                                                    1.79769e+308
# scaleRandomPercent                                                          False
# scaleSubsLevelSize                                                     2147483647
# scaleTable
# settlingFirm
# sharesAllocation                                        1574095737.0/U9509931/100
# shortSaleSlot                                                                   0
# smartComboRoutingParams                                                      None
# smartComboRoutingParamsCount                                                    0
# softDollarTier                                                                 =,
# solicited                                                                   False
# startingPrice                                                        1.79769e+308
# stockRangeLower                                                      1.79769e+308
# stockRangeUpper                                                      1.79769e+308
# stockRefPrice                                                        1.79769e+308
# sweepToFill                                                                 False
# tif                                                                           GTC
# totalQuantity                                                                 162
# trailStopPrice                                                               7.15
# trailingPercent                                                      1.79769e+308
# transmit                                                                     True
# triggerMethod                                                                   0
# triggerPrice                                                         1.79769e+308
# volatility                                                           1.79769e+308
# volatilityType                                                                  0
# whatIf                                                                      False
# time_added                                             2018-11-27 22:45:16.174621
# Name: 6, Length: 155, dtype: object
# 200
# IB error id 200 errorcode 202 string Order Canceled - reason:
# Considering placing sell order for ROSE
# Existing sell order in place. Skipping
# Considering placing sell order for STRO
# Position held for less than 2 days. Skipping
# Considering placing sell order for MBIO
# Position held for less than 2 days. Skipping
# Considering placing sell order for MGEN
# Position held for less than 2 days. Skipping
# Considering placing sell order for UROV
# Position held for less than 2 days. Skipping
# Considering placing sell order for CUE
# Position held for less than 2 days. Skipping
# Considering placing sell order for ASPN
# Position held for less than 2 days. Skipping
# Considering placing sell order for BTAI
# Existing sell order in place. Skipping
# Considering placing sell order for FTNW
# Existing sell order in place. Skipping
# Considering placing sell order for CERC
# Do not have a position. Skipping
# Considering placing sell order for SBT
# Position held for less than 2 days. Skipping
# Considering placing sell order for KEG
# Position held for less than 2 days. Skipping
# Considering placing sell order for ICD
# Do not have a position. Skipping
# Considering placing sell order for ETTX
# Position held for less than 2 days. Skipping
# Considering placing sell order for RMED
# Position held for less than 2 days. Skipping
# Considering placing sell order for CRVS
# Position held for less than 2 days. Skipping
# Considering placing sell order for ATOM
# Position held for less than 2 days. Skipping
# Considering placing sell order for IMH
# Position held for less than 2 days. Skipping
# Considering placing sell order for BSGM
# Position held for less than 2 days. Skipping
# Considering placing sell order for MGTA
# Position held for less than 2 days. Skipping
# Considering placing sell order for USD
# USD is a cash position. Not for sale
# Considering placing sell order for AEYE
# Do not have a position. Skipping
# Considering placing sell order for SPRO
# Position held for less than 2 days. Skipping
# Considering placing sell order for RKDA
# Existing sell order in place. Skipping
# Considering placing sell order for SIC
# Existing sell order in place. Skipping
# 0	Buying_power: 100000
# Considering trading this stock: RMED
# Wont trade this RMED
# In positions?: True	In open_orders?: False	Traded today?: True
# 1	Buying_power: 100000
# Considering trading this stock: STRO
# Wont trade this STRO
# In positions?: True	In open_orders?: False	Traded today?: True
# 2	Buying_power: 100000
# Considering trading this stock: UROV
# Wont trade this UROV
# In positions?: True	In open_orders?: False	Traded today?: True
# 3	Buying_power: 100000
# Considering trading this stock: PHAS
# Getting full contract details from the server...
# got multiple contracts using first one
# 337739826,PHAS,STK,,0.0,,,SMART,NASDAQ,USD,PHAS,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 3.1
# Buying PHAS, 	shares: 327, 	price: 3.05
# Using order id of 201
# Placed order, orderid is 201
# 4	Buying_power: 100000
# Considering trading this stock: OSMT
# Getting full contract details from the server...
# got multiple contracts using first one
# 337007050,OSMT,STK,,0.0,,,SMART,NASDAQ,USD,OSMT,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 7.1
# Buying OSMT, 	shares: 142, 	price: 7.0
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 202
# Placed order, orderid is 202
# 5	Buying_power: 100000
# Considering trading this stock: SVVC
# Getting full contract details from the server...
# got multiple contracts using first one
# 86823361,SVVC,STK,,0.0,,,SMART,NASDAQ,USD,SVVC,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: SVVC@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 6	Buying_power: 100000
# Considering trading this stock: VOC
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Getting full contract details from the server...
# got multiple contracts using first one
# 87741352,VOC,STK,,0.0,,,SMART,NYSE,USD,VOC,VOC,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 4.1503
# Buying VOC, 	shares: 243, 	price: 4.1
# Using order id of 203
# Placed order, orderid is 203
# 7	Buying_power: 100000
# Considering trading this stock: SAEX
# Getting full contract details from the server...
# got multiple contracts using first one
# 333484942,SAEX,STK,,0.0,,,SMART,NASDAQ,USD,SAEX,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 3.95
# Buying SAEX, 	shares: 256, 	price: 3.9
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 204
# Placed order, orderid is 204
# 8	Buying_power: 100000
# Considering trading this stock: NTRP
# Getting full contract details from the server...
# got multiple contracts using first one
# 262067284,NTRP,STK,,0.0,,,SMART,NASDAQ,USD,NTRP,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 6.75
# Buying NTRP, 	shares: 150, 	price: 6.65
# Using order id of 205
# Placed order, orderid is 205
# 9	Buying_power: 100000
# Considering trading this stock: LOOP
# Getting full contract details from the server...
# got multiple contracts using first one
# 212708817,LOOP,STK,,0.0,,,SMART,NASDAQ,USD,LOOP,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: LOOP@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 10	Buying_power: 100000
# Considering trading this stock: AEYE
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Wont trade this AEYE
# In positions?: True	In open_orders?: False	Traded today?: True
# 11	Buying_power: 100000
# Considering trading this stock: EAST
# Getting full contract details from the server...
# got multiple contracts using first one
# 279261014,EAST,STK,,0.0,,,SMART,NASDAQ,USD,EAST,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 6.44
# Buying EAST, 	shares: 157, 	price: 6.35
# Using order id of 206
# Placed order, orderid is 206
# 12	Buying_power: 100000
# Considering trading this stock: ONTX
# Getting full contract details from the server...
# got multiple contracts using first one
# 335035049,ONTX,STK,,0.0,,,SMART,NASDAQ,USD,ONTX,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 3.84
# Buying ONTX, 	shares: 263, 	price: 3.8
# Using order id of 207
# Placed order, orderid is 207
# 13	Buying_power: 100000
# Considering trading this stock: BCRH
# Getting full contract details from the server...
# got multiple contracts using first one
# 137837019,BCRH,STK,,0.0,,,SMART,NYSE,USD,BCRH,BCRH,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 6.0
# Buying BCRH, 	shares: 169, 	price: 5.9
# Using order id of 208
# Placed order, orderid is 208
# 14	Buying_power: 100000
# Considering trading this stock: AGFS
# Getting full contract details from the server...
# got multiple contracts using first one
# 202007772,AGFS,STK,,0.0,,,SMART,NASDAQ,USD,AGFS,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 3.93
# Buying AGFS, 	shares: 259, 	price: 3.85
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 209
# Placed order, orderid is 209
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm.nj
# IB error id -1 errorcode 2104 string Market data farm connection is OK:usfuture
# IB error id -1 errorcode 2104 string Market data farm connection is OK:eufarm
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds.us
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ilhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:hkhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:fundfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds
# Cancelling this order: avgFillPrice                                                                    0
# clientId                                                                        1
# filled                                                                          0
# id                                                                            201
# lastFillPrice                                                                   0
# mktCapPrice                                                                     0
# orderstate                      <ibapi.order_state.OrderState object at 0x1106...
# parentId                                                                        0
# permid                                                                 1574096668
# status                                                                  Submitted
# whyHeld
# comboLegs                                                                    None
# comboLegsCount                                                                  0
# comboLegsDescrip
# conId                                                                   337739826
# currency                                                                      USD
# deltaNeutralContract                                                         None
# deltaNeutralContractPresent                                                 False
# exchange                                                                    SMART
# includeExpired                                                              False
# lastTradeDateOrContractMonth
# localSymbol                                                                  PHAS
# multiplier
# primaryExchange
# right                                                                           ?
# secId
# secIdType
# secType                                                                       STK
# strike                                                                          0
# symbol                                                                       PHAS
#                                                       ...
# scalePriceAdjustInterval                                               2147483647
# scalePriceAdjustValue                                                1.79769e+308
# scalePriceIncrement                                                  1.79769e+308
# scaleProfitOffset                                                    1.79769e+308
# scaleRandomPercent                                                          False
# scaleSubsLevelSize                                                     2147483647
# scaleTable
# settlingFirm
# sharesAllocation                                        1574096668.0/U9509931/100
# shortSaleSlot                                                                   0
# smartComboRoutingParams                                                      None
# smartComboRoutingParamsCount                                                    0
# softDollarTier                                                                 =,
# solicited                                                                   False
# startingPrice                                                        1.79769e+308
# stockRangeLower                                                      1.79769e+308
# stockRangeUpper                                                      1.79769e+308
# stockRefPrice                                                        1.79769e+308
# sweepToFill                                                                 False
# tif                                                                           GTC
# totalQuantity                                                                 327
# trailStopPrice                                                               4.05
# trailingPercent                                                      1.79769e+308
# transmit                                                                     True
# triggerMethod                                                                   0
# triggerPrice                                                         1.79769e+308
# volatility                                                           1.79769e+308
# volatilityType                                                                  0
# whatIf                                                                      False
# time_added                                             2018-11-27 22:56:41.521973
# Name: 4, Length: 155, dtype: object
# 201
# IB error id 201 errorcode 202 string Order Canceled - reason:
# Cancelling this order: avgFillPrice                                                                    0
# clientId                                                                        1
# filled                                                                          0
# id                                                                            202
# lastFillPrice                                                                   0
# mktCapPrice                                                                     0
# orderstate                      <ibapi.order_state.OrderState object at 0x1101...
# parentId                                                                        0
# permid                                                                 1574096793
# status                                                                  Submitted
# whyHeld
# comboLegs                                                                    None
# comboLegsCount                                                                  0
# comboLegsDescrip
# conId                                                                   337007050
# currency                                                                      USD
# deltaNeutralContract                                                         None
# deltaNeutralContractPresent                                                 False
# exchange                                                                    SMART
# includeExpired                                                              False
# lastTradeDateOrContractMonth
# localSymbol                                                                  OSMT
# multiplier
# primaryExchange
# right                                                                           ?
# secId
# secIdType
# secType                                                                       STK
# strike                                                                          0
# symbol                                                                       OSMT
#                                                       ...
# scalePriceAdjustInterval                                               2147483647
# scalePriceAdjustValue                                                1.79769e+308
# scalePriceIncrement                                                  1.79769e+308
# scaleProfitOffset                                                    1.79769e+308
# scaleRandomPercent                                                          False
# scaleSubsLevelSize                                                     2147483647
# scaleTable
# settlingFirm
# sharesAllocation                                        1574096793.0/U9509931/100
# shortSaleSlot                                                                   0
# smartComboRoutingParams                                                      None
# smartComboRoutingParamsCount                                                    0
# softDollarTier                                                                 =,
# solicited                                                                   False
# startingPrice                                                        1.79769e+308
# stockRangeLower                                                      1.79769e+308
# stockRangeUpper                                                      1.79769e+308
# stockRefPrice                                                        1.79769e+308
# sweepToFill                                                                 False
# tif                                                                           GTC
# totalQuantity                                                                 142
# trailStopPrice                                                                  8
# trailingPercent                                                      1.79769e+308
# transmit                                                                     True
# triggerMethod                                                                   0
# triggerPrice                                                         1.79769e+308
# volatility                                                           1.79769e+308
# volatilityType                                                                  0
# whatIf                                                                      False
# time_added                                             2018-11-27 22:56:55.727910
# Name: 5, Length: 155, dtype: object
# 202
# IB error id 202 errorcode 202 string Order Canceled - reason:
# Cancelling this order: avgFillPrice                                                                    0
# clientId                                                                        1
# filled                                                                          0
# id                                                                            203
# lastFillPrice                                                                   0
# mktCapPrice                                                                     0
# orderstate                      <ibapi.order_state.OrderState object at 0x1105...
# parentId                                                                        0
# permid                                                                 1574097042
# status                                                                  Submitted
# whyHeld
# ...
# smartComboRoutingParams                                                      None
# smartComboRoutingParamsCount                                                    0
# softDollarTier                                                                 =,
# solicited                                                                   False
# startingPrice                                                        1.79769e+308
# stockRangeLower                                                      1.79769e+308
# stockRangeUpper                                                      1.79769e+308
# stockRefPrice                                                        1.79769e+308
# sweepToFill                                                                 False
# tif                                                                           GTC
# totalQuantity                                                                 194
# trailStopPrice                                                               6.15
# trailingPercent                                                      1.79769e+308
# transmit                                                                     True
# triggerMethod                                                                   0
# triggerPrice                                                         1.79769e+308
# volatility                                                           1.79769e+308
# volatilityType                                                                  0
# whatIf                                                                      False
# time_added                                             2018-11-27 23:10:17.526490
# Name: 3, Length: 155, dtype: object
# 211
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm.nj
# IB error id -1 errorcode 2104 string Market data farm connection is OK:usfuture
# IB error id -1 errorcode 2104 string Market data farm connection is OK:eufarm
# IB error id -1 errorcode 2104 string Market data farm connection is OK:njfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds.us
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ilhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:hkhmds
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:fundfarm
# IB error id -1 errorcode 2106 string HMDS data farm connection is OK:ushmds
# IB error id 211 errorcode 202 string Order Canceled - reason:
# Considering placing sell order for ROSE
# Existing sell order in place. Skipping
# Considering placing sell order for STRO
# Position held for less than 2 days. Skipping
# Considering placing sell order for MBIO
# Position held for less than 2 days. Skipping
# Considering placing sell order for MGEN
# Position held for less than 2 days. Skipping
# Considering placing sell order for UROV
# Position held for less than 2 days. Skipping
# Considering placing sell order for CUE
# Position held for less than 2 days. Skipping
# Considering placing sell order for ASPN
# Position held for less than 2 days. Skipping
# Considering placing sell order for BTAI
# Existing sell order in place. Skipping
# Considering placing sell order for FTNW
# Existing sell order in place. Skipping
# Considering placing sell order for CERC
# Do not have a position. Skipping
# Considering placing sell order for SBT
# Position held for less than 2 days. Skipping
# Considering placing sell order for KEG
# Position held for less than 2 days. Skipping
# Considering placing sell order for ICD
# Do not have a position. Skipping
# Considering placing sell order for ETTX
# Position held for less than 2 days. Skipping
# Considering placing sell order for RMED
# Position held for less than 2 days. Skipping
# Considering placing sell order for CRVS
# Position held for less than 2 days. Skipping
# Considering placing sell order for ATOM
# Position held for less than 2 days. Skipping
# Considering placing sell order for IMH
# Position held for less than 2 days. Skipping
# Considering placing sell order for NTRP
# Position held for less than 2 days. Skipping
# Considering placing sell order for LMB
# Position held for less than 2 days. Skipping
# Considering placing sell order for BSGM
# Position held for less than 2 days. Skipping
# Considering placing sell order for MGTA
# Position held for less than 2 days. Skipping
# Considering placing sell order for USD
# USD is a cash position. Not for sale
# Considering placing sell order for AEYE
# Do not have a position. Skipping
# Considering placing sell order for SPRO
# Position held for less than 2 days. Skipping
# Considering placing sell order for RKDA
# Existing sell order in place. Skipping
# Considering placing sell order for SIC
# Existing sell order in place. Skipping
# 0	Buying_power: 100000
# Considering trading this stock: ATOM
# Wont trade this ATOM
# In positions?: True	In open_orders?: False	Traded today?: True
# 1	Buying_power: 100000
# Considering trading this stock: PTGX
# Getting full contract details from the server...
# got multiple contracts using first one
# 243505376,PTGX,STK,,0.0,,,SMART,NASDAQ,USD,PTGX,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 7.16
# Buying PTGX, 	shares: 141, 	price: 7.05
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 218
# Placed order, orderid is 218
# 2	Buying_power: 100000
# Considering trading this stock: IEA
# IB error id 218 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19070.64 USD] is insufficient to cover the Initial Margin requirement of [19109.24 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 312272781,IEA,STK,,0.0,,,SMART,NASDAQ,USD,IEA,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 7.99
# Buying IEA, 	shares: 126, 	price: 7.9
# Using order id of 219
# Placed order, orderid is 219
# 3	Buying_power: 100000
# Considering trading this stock: FLGT
# IB error id 219 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19070.64 USD] is insufficient to cover the Initial Margin requirement of [19106.67 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 249323303,FLGT,STK,,0.0,,,SMART,NASDAQ,USD,FLGT,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 3.23
# Buying FLGT, 	shares: 317, 	price: 3.15
# Using order id of 220
# Placed order, orderid is 220
# 4	Buying_power: 100000
# Considering trading this stock: AZRE
# IB error id 220 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19070.64 USD] is insufficient to cover the Initial Margin requirement of [19106.59 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 251284591,AZRE,STK,,0.0,,,SMART,NYSE,USD,AZRE,AZRE,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 10.44
# Buying AZRE, 	shares: 97, 	price: 10.3
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 221
# Placed order, orderid is 221
# 5	Buying_power: 100000
# Considering trading this stock: KEG
# Wont trade this KEG
# In positions?: True	In open_orders?: False	Traded today?: True
# 6	Buying_power: 100000
# Considering trading this stock: LPTX
# Getting full contract details from the server...
# got multiple contracts using first one
# 263760390,LPTX,STK,,0.0,,,SMART,NASDAQ,USD,LPTX,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 3.57
# Buying LPTX, 	shares: 285, 	price: 3.5
# Using order id of 222
# Placed order, orderid is 222
# 7	Buying_power: 100000
# Considering trading this stock: METC
# IB error id 222 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19072.00 USD] is insufficient to cover the Initial Margin requirement of [19116.99 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 264549084,METC,STK,,0.0,,,SMART,NASDAQ,USD,METC,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 4.88
# Buying METC, 	shares: 208, 	price: 4.8
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 223
# Placed order, orderid is 223
# 8	Buying_power: 100000
# Considering trading this stock: OVID
# IB error id 223 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19072.00 USD] is insufficient to cover the Initial Margin requirement of [19111.50 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 275215219,OVID,STK,,0.0,,,SMART,NASDAQ,USD,OVID,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 4.18
# Buying OVID, 	shares: 243, 	price: 4.1
# Using order id of 224
# Placed order, orderid is 224
# 9	Buying_power: 100000
# Considering trading this stock: ASV
# IB error id 224 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19072.41 USD] is insufficient to cover the Initial Margin requirement of [19097.34 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 275951391,ASV,STK,,0.0,,,SMART,NASDAQ,USD,ASV,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 3.44
# Buying ASV, 	shares: 294, 	price: 3.4
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 225
# Placed order, orderid is 225
# 10	Buying_power: 100000
# Considering trading this stock: NESR
# Getting full contract details from the server...
# IB error id 225 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19072.41 USD] is insufficient to cover the Initial Margin requirement of [19103.61 USD]
#
# got multiple contracts using first one
# 278169018,NESR,STK,,0.0,,,SMART,NASDAQ,USD,NESR,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: NESR@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# 11	Buying_power: 100000
# Considering trading this stock: PLYM
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Getting full contract details from the server...
# got multiple contracts using first one
# 278545614,PLYM,STK,,0.0,,,SMART,AMEX,USD,PLYM,PLYM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 12.26
# Buying PLYM, 	shares: 82, 	price: 12.1
# Using order id of 226
# Placed order, orderid is 226
# 12	Buying_power: 100000
# Considering trading this stock: SGBX
# Getting full contract details from the server...
# IB error id 226 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19037.21 USD] is insufficient to cover the Initial Margin requirement of [19095.38 USD]
#
# got multiple contracts using first one
# 269258813,SGBX,STK,,0.0,,,SMART,NASDAQ,USD,SGBX,SCM,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Current price: 3.3662
# Buying SGBX, 	shares: 303, 	price: 3.3
# Using order id of 227
# Placed order, orderid is 227
# 13	Buying_power: 100000
# Considering trading this stock: MRSN
# IB error id 227 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19031.82 USD] is insufficient to cover the Initial Margin requirement of [19078.57 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 280803808,MRSN,STK,,0.0,,,SMART,NASDAQ,USD,MRSN,NMS,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# Current price: 5.89
# Buying MRSN, 	shares: 172, 	price: 5.8
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Using order id of 228
# Placed order, orderid is 228
# 14	Buying_power: 100000
# Considering trading this stock: NRCG
# IB error id 228 errorcode 201 string Order rejected - reason:Your order is not accepted because your Equity with Loan Value of [19031.82 USD] is insufficient to cover the Initial Margin requirement of [19075.02 USD]
#
# Getting full contract details from the server...
# got multiple contracts using first one
# 337030519,NRCG,STK,,0.0,,,SMART,AMEX,USD,NRCG,NRCG,False,,combo:
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 366 string No historical data query found for ticker id:50
# Could not get latest_trade_price. Getting historical closing price
# Getting historical data from the server... could take 20 seconds to complete
# IB error id 50 errorcode 162 string Historical Market Data Service error message:HMDS query returned no data: NRCG@SMART Trades
# Exceeded maximum wait for wrapper to confirm finished - seems to be normal behaviour
# Did not receive historical data. Setting current_price as nan
# Current price: nan
# Could not get current price. Skipping for now
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-4772156ae5b7> in <module>()
# ----> 1 app.main_trading()
#
# ~/Documents/Algo Trading/BroCodePC/IB_API_tutorial.py in main_trading(self)
#    1472
#    1473             # Wait for the rebalance_interval time (in minutes)
# -> 1474             time.sleep(self.rebalance_interval * 60)
#    1475
#    1476             # Reset current time `now`
#
# KeyboardInterrupt:
