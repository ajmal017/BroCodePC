# %%
from zipline.api import order, record, symbol
import pandas as pd
# %load_ext zipline

# %%
def initialize(context):
    pass


def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), 'price'))

# %% [markdown]
# ## Sample 1

# %%
# %%zipline --start 2016-1-1 --end 2018-1-1
# from zipline.api import symbol, order, record
# def initialize(context):
#     pass
#
#
# def handle_data(context, data):
#     order(symbol('AAPL'), 10)
#     record(AAPL=data.current(symbol('AAPL'), 'price'))

# %% [markdown]
# ## Sample 2

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 -o dma.pickle
#
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
# import pylab
#
# pylab.show()
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.ix[[t != [] for t in perf.transactions]]
#     buys = perf_trans.ix[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.ix[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.ix[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.ix[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()

# %%
# Check what bundles we have
# !zipline bundles
# Out:
# csvdir <no ingestions>
# quandl 2018-10-09 16:02:44.622222
# quantopian-quandl 2018-10-19 16:18:21.978780
# quantopian-quandl 2018-10-13 09:47:32.118860

# %%
# !zipline ingest -b quantopian-quandl
# Out:
# Downloading Bundle: quantopian-quandl  [####################################]  100%
# [2018-10-19 16:19:00.470950] INFO: zipline.data.bundles.quandl: Writing data to /Users/chingaling/.zipline/data/quantopian-quandl/2018-10-19T16;18;21.978780.

# %%
# Set my QUANDL API key to get data ingestions
# !QUANDL_API_KEY=quVuWkvuQ3apyVKhxets zipline ingest

# %% [markdown]
# # Copied holding_30 algo from Quantopian below
# Edited to adapt to zipline package (instead of Quantopian packages)

# %%
from zipline import api as za
from zipline import run_algorithm
from zipline.pipeline import Pipeline
from zipline.pipeline.data import USEquityPricing
from zipline.finance import slippage, commission, blotter
from zipline.finance.execution import LimitOrder
#from zipline.pipeline.data import morningstar
from zipline.pipeline.factors import SimpleMovingAverage, AverageDollarVolume
#from zipline.pipeline.filters.morningstar import IsPrimaryShare

import numpy as np #needed for NaN handling
import math #ceil and floor are useful for rounding

from itertools import cycle

# %%
def initialize(context):
    #za.set_commission(commission.PerShare(cost=0.01, min_trade_cost=1.50))
    za.set_slippage(slippage.VolumeShareSlippage(volume_limit=.20, price_impact=0.0))
    #za.set_slippage(slippage.FixedSlippage(spread=0.00))
    za.set_commission(commission.PerTrade(cost=0.00))
    #za.set_slippage(slippage.FixedSlippage(spread=0.00))
    za.set_long_only()

    context.MaxCandidates=100
    context.MaxBuyOrdersAtOnce=60
    context.MyLeastPrice=3.00
    context.MyMostPrice=20.00
    context.MyFireSalePrice=context.MyLeastPrice
    context.MyFireSaleAge=6

    # over simplistic tracking of position age
    context.age={}
    print (len(context.portfolio.positions))

    # Rebalance
    EveryThisManyMinutes=10
    TradingDayHours=6.5
    TradingDayMinutes=int(TradingDayHours*60)
    for minutez in range(
        1, 
        TradingDayMinutes, 
        EveryThisManyMinutes
    ):
        za.schedule_function(my_rebalance, za.date_rules.every_day(), za.time_rules.market_open(minutes=minutez))

    # Prevent excessive logging of canceled orders at market close.
    za.schedule_function(cancel_open_orders, za.date_rules.every_day(), za.time_rules.market_close(hours=0, minutes=1))

    # Record variables at the end of each day.
    za.schedule_function(my_record_vars, za.date_rules.every_day(), za.time_rules.market_close())

    # Create our pipeline and attach it to our algorithm.
    my_pipe = make_pipeline(context)
    za.attach_pipeline(my_pipe, 'my_pipeline')

# %%
def make_pipeline(context):
    """
    Create our pipeline.
    """

#     # Filter for primary share equities. IsPrimaryShare is a built-in filter.
#     primary_share = IsPrimaryShare()

#     # Equities listed as common stock (as opposed to, say, preferred stock).
#     # 'ST00000001' indicates common stock.
#     common_stock = morningstar.share_class_reference.security_type.latest.eq('ST00000001')

#     # Non-depositary receipts. Recall that the ~ operator inverts filters,
#     # turning Trues into Falses and vice versa
#     not_depositary = ~morningstar.share_class_reference.is_depositary_receipt.latest

#     # Equities not trading over-the-counter.
#     not_otc = ~morningstar.share_class_reference.exchange_id.latest.startswith('OTC')

#     # Not when-issued equities.
#     not_wi = ~morningstar.share_class_reference.symbol.latest.endswith('.WI')

#     # Equities without LP in their name, .matches does a match using a regular
#     # expression
#     not_lp_name = ~morningstar.company_reference.standard_name.latest.matches('.* L[. ]?P.?$')

#     # Equities with a null value in the limited_partnership Morningstar
#     # fundamental field.
#     not_lp_balance_sheet = morningstar.balance_sheet.limited_partnership.latest.isnull()

#     # Equities whose most recent Morningstar market cap is not null have
#     # fundamental data and therefore are not ETFs.
#     have_market_cap = morningstar.valuation.market_cap.latest.notnull()

    # At least a certain price
    price = USEquityPricing.close.latest
    AtLeastPrice   = (price >= context.MyLeastPrice)
    AtMostPrice    = (price <= context.MyMostPrice)

    # Taking out all of the other filters for now, until I can figure out how to feed them back in
    # Filter for stocks that pass all of our previous filters.
#     tradeable_stocks = (
#         primary_share
#         & common_stock
#         & not_depositary
#         & not_otc
#         & not_wi
#         & not_lp_name
#         & not_lp_balance_sheet
#         & have_market_cap
#         & AtLeastPrice
#         & AtMostPrice
#     )
    
    # Using this for now until I can get stock metadata in the filter
    tradeable_stocks = (
        AtLeastPrice
        & AtMostPrice
    )

    LowVar=6
    HighVar=40

    print('\nAlgorithm initialized variables:\n context.MaxCandidates %s \n LowVar %s \n HighVar %s'
        % (context.MaxCandidates, LowVar, HighVar)
    )

    # High dollar volume filter.
    base_universe = AverageDollarVolume(
        window_length=20,
        mask=tradeable_stocks
    ).percentile_between(LowVar, HighVar)

    # Short close price average.
    ShortAvg = SimpleMovingAverage(
        inputs=[USEquityPricing.close],
        window_length=3,
        mask=base_universe
    )

    # Long close price average.
    LongAvg = SimpleMovingAverage(
        inputs=[USEquityPricing.close],
        window_length=45,
        mask=base_universe
    )

    percent_difference = (ShortAvg - LongAvg) / LongAvg

    # Filter to select securities to long.
    stocks_worst = percent_difference.bottom(context.MaxCandidates)
    securities_to_trade = (stocks_worst)
    
    import ipdb; ipdb.set_trace() # BREAKPOINT
    
    return Pipeline(
        columns={
            'stocks_worst': stocks_worst
        },
        screen=(securities_to_trade),
    )

# %%
def my_compute_weights(context):
    """
    Compute ordering weights.
    """
    # Compute even target weights for our long positions and short positions.
    stocks_worst_weight = 1.00/len(context.stocks_worst)

    return stocks_worst_weight

# %%
def before_trading_start(context, data):
    # Review previous transactions using Blotter
    
    blot_history = blotter.blotter.Blotter.get_transactions()
    
    # Gets our pipeline output every day.
    context.output = za.pipeline_output('my_pipeline')

    context.stocks_worst = context.output[context.output['stocks_worst']].index.tolist()
    
    print ("stocks_worst: {}".format(context.stocks_worst))
    
    context.stocks_worst_weight = my_compute_weights(context)

    context.MyCandidate = cycle(context.stocks_worst)
    
    context.LowestPrice=context.MyLeastPrice #reset beginning of day
    print (len(context.portfolio.positions))
    for stock in context.portfolio.positions:
        CurrPrice = float(data.current([stock], 'price'))
        if CurrPrice<context.LowestPrice:
            context.LowestPrice = CurrPrice
        if stock in context.age:
            context.age[stock] += 1
        else:
            context.age[stock] = 1
    for stock in context.age:
        if stock not in context.portfolio.positions:
            context.age[stock] = 0
        message = 'stock.symbol: {symbol}  :  age: {age}'
        print(message.format(symbol=stock.symbol, age=context.age[stock]))

    pass

# %%
def my_rebalance(context, data):
    BuyFactor=.99
    SellFactor=1.01
    cash=context.portfolio.cash

    cancel_open_buy_orders(context, data)

    # Order sell at profit target in hope that somebody actually buys it
    for stock in context.portfolio.positions:
        if not get_open_orders(stock):
            StockShares = context.portfolio.positions[stock].amount
            CurrPrice = float(data.current([stock], 'price'))
            CostBasis = float(context.portfolio.positions[stock].cost_basis)
            SellPrice = float(make_div_by_05(CostBasis*SellFactor, buy=False))
            
            
            if np.isnan(SellPrice) :
                pass # probably best to wait until nan goes away
            elif (stock in context.age and context.age[stock] == 1) :
                pass
            elif (
                stock in context.age 
                and context.MyFireSaleAge<=context.age[stock] 
                and (
                    context.MyFireSalePrice>CurrPrice
                    or CostBasis>CurrPrice
                )
            ):
                if (stock in context.age and context.age[stock] < 2) :
                    pass
                elif stock not in context.age:
                    context.age[stock] = 1
                else:
                    SellPrice = float(make_div_by_05(.95*CurrPrice, buy=False))
                    print("Selling {}, \tshares: {}, \tprice: {}".format(stock, StockShares, SellPrice))
                    order(stock, -StockShares,
                        style=LimitOrder(SellPrice)
                    )
            else:
                if (stock in context.age and context.age[stock] < 2) :
                    pass
                elif stock not in context.age:
                    context.age[stock] = 1
                else:
                    print("Selling {}, \tshares: {}, \tprice: {}".format(stock, StockShares, SellPrice))
                    order(stock, -StockShares,
                        style=LimitOrder(SellPrice)
                    )

    WeightThisBuyOrder=float(1.00/context.MaxBuyOrdersAtOnce)
    for ThisBuyOrder in range(context.MaxBuyOrdersAtOnce):
        stock = next(context.MyCandidate)
        PH = data.history([stock], 'price', 20, '1d')
        PH_Avg = float(PH.mean())
        CurrPrice = float(data.current([stock], 'price'))
        if np.isnan(CurrPrice):
            pass # probably best to wait until nan goes away
        else:
            if CurrPrice > float(1.25*PH_Avg):
                BuyPrice=float(CurrPrice)
            else:
                BuyPrice=float(CurrPrice*BuyFactor)
            BuyPrice=float(make_div_by_05(BuyPrice, buy=True))
            StockShares = int(WeightThisBuyOrder*cash/BuyPrice)
            print("Buying {}, \tshares: {}, \tprice: {}".format(stock, StockShares, BuyPrice))
            order(stock, StockShares,
                style=LimitOrder(BuyPrice)
            )

# %%
#if cents not divisible by .05, round down if buy, round up if sell
def make_div_by_05(s, buy=False):
    s *= 20.00
    s =  math.floor(s) if buy else math.ceil(s)
    s /= 20.00
    return s

# %%
def my_record_vars(context, data):
    """
    Record variables at the end of each day.
    """

    # Record our variables.
    record(leverage=context.account.leverage)
    record(positions=len(context.portfolio.positions))
    if 0<len(context.age):
        MaxAge=context.age[max(context.age.keys(), key=(lambda k: context.age[k]))]
        print (MaxAge)
        record(MaxAge=MaxAge)
    record(LowestPrice=context.LowestPrice)

# %%
def log_open_order(StockToLog):
    oo = za.get_open_orders()
    if len(oo) == 0:
        return
    for stock, orders in oo.items():
        if stock == StockToLog:
            for order in orders:
                message = 'Found open order for {amount} shares in {stock}'
                print(message.format(amount=order.amount, stock=stock))

# %%
def log_open_orders():
    oo = za.get_open_orders()
    if len(oo) == 0:
        return
    for stock, orders in oo.items():
        for order in orders:
            message = 'Found open order for {amount} shares in {stock}'
            print(message.format(amount=order.amount, stock=stock))

# %%
def cancel_open_buy_orders(context, data):
    oo = za.get_open_orders()
    if len(oo) == 0:
        return
    for stock, orders in oo.items():
        for order in orders:
            #message = 'Canceling order of {amount} shares in {stock}'
            #print(message.format(amount=order.amount, stock=stock))
            if 0<order.amount: #it is a buy order
                za.cancel_order(order)

# %%
def cancel_open_orders(context, data):
    oo = za.get_open_orders()
    if len(oo) == 0:
        return
    for stock, orders in oo.items():
        for order in orders:
            #message = 'Canceling order of {amount} shares in {stock}'
            #print(message.format(amount=order.amount, stock=stock))
            za.cancel_order(order)

# %%
# This is the every minute stuff
def handle_data(context, data):
    pass

# %%
# %zipline --start 2018-1-1 --end 2018-1-3 -o dma.pickle
# Out:
# 0
#
# Algorithm initialized variables:
#  context.MaxCandidates 100
#  LowVar 6
#  HighVar 40
# > <ipython-input-18-3965b038a3f8>(96)make_pipeline()
#      95
# ---> 96     return Pipeline(
#      97         columns={
#
# ipdb> c
# /anaconda3/envs/env_zipline/lib/python3.5/site-packages/zipline/pipeline/filters/filter.py:382: RuntimeWarning: invalid value encountered in less_equal
#   return (lower_bounds <= data) & (data <= upper_bounds)
# stocks_worst: [Equity(40 [ACRE]), Equity(42 [ACTG]), Equity(47 [ADES]), Equity(88 [AGTC]), Equity(161 [AMSWA]), Equity(190 [AOSL]), Equity(191 [AP]), Equity(232 [ASC]), Equity(271 [AVHI]), Equity(275 [AVNW]), Equity(278 [AVX]), Equity(327 [BCOV]), Equity(348 [BFIN]), Equity(414 [BPI]), Equity(520 [CCXI]), Equity(527 [CECE]), Equity(534 [CERS]), Equity(556 [CHFN]), Equity(570 [CIA]), Equity(591 [CLFD]), Equity(599 [CLUB]), Equity(637 [COBZ]), Equity(721 [CSWC]), Equity(786 [DAKT]), Equity(818 [DGII]), Equity(823 [DHT]), Equity(867 [DSPG]), Equity(910 [ECYT]), Equity(935 [ELGX]), Equity(961 [ENZ]), Equity(1029 [EXXI]), Equity(1062 [FDUS]), Equity(1068 [FF]), Equity(1131 [FRBK]), Equity(1141 [FRSH]), Equity(1153 [FTD]), Equity(1177 [GARS]), Equity(1196 [GEOS]), Equity(1215 [GLAD]), Equity(1236 [GNE]), Equity(1237 [GNMK]), Equity(1273 [GSVC]), Equity(1377 [HOS]), Equity(1434 [I]), Equity(1544 [IVAC]), Equity(1567 [JMBA]), Equity(1616 [KODK]), Equity(1622 [KPTI]), Equity(1646 [LAYN]), Equity(1649 [LBAI]), Equity(1655 [LCUT]), Equity(1700 [LNDC]), Equity(1719 [LQDT]), Equity(1749 [MACK]), Equity(1769 [MCC]), Equity(1830 [MITK]), Equity(1850 [MN]), Equity(1876 [MPX]), Equity(1897 [MSL]), Equity(1930 [MYE]), Equity(2031 [NSTG]), Equity(2103 [OMED]), Equity(2108 [OMN]), Equity(2129 [ORM]), Equity(2178 [PCYG]), Equity(2201 [PETX]), Equity(2222 [PHIIK]), Equity(2226 [PICO]), Equity(2282 [PPHM]), Equity(2333 [PZN]), Equity(2379 [RECN]), Equity(2428 [RMTI]), Equity(2430 [RNET]), Equity(2457 [RRTS]), Equity(2462 [RSO]), Equity(2470 [RTIX]), Equity(2478 [RVLT]), Equity(2492 [SALM]), Equity(2501 [SB]), Equity(2542 [SFE]), Equity(2563 [SHLO]), Equity(2637 [SPNS]), Equity(2697 [SUNS]), Equity(2698 [SUP]), Equity(2743 [TAX
# Buying Equity(471 [CALX]), 	shares: 29761, 	price: 5.6
# Buying Equity(519 [CCRN]), 	shares: 13440, 	price: 12.4
# Buying Equity(527 [CECE]), 	shares: 32051, 	price: 5.2
# Buying Equity(556 [CHFN]), 	shares: 9337, 	price: 17.85
# Buying Equity(570 [CIA]), 	shares: 22222, 	price: 7.5
# Buying Equity(591 [CLFD]), 	shares: 13774, 	price: 12.1
# Buying Equity(599 [CLUB]), 	shares: 30303, 	price: 5.5
# Buying Equity(700 [CRY]), 	shares: 8658, 	price: 19.25
# Buying Equity(702 [CSBK]), 	shares: 10010, 	price: 16.65
# Buying Equity(714 [CSLT]), 	shares: 43859, 	price: 3.8
# Buying Equity(721 [CSWC]), 	shares: 10070, 	price: 16.55
# Buying Equity(765 [CWCO]), 	shares: 13175, 	price: 12.65
# Buying Equity(786 [DAKT]), 	shares: 17825, 	price: 9.35
# Buying Equity(817 [DGICA]), 	shares: 9746, 	price: 17.1
# Buying Equity(867 [DSPG]), 	shares: 13440, 	price: 12.4
# Buying Equity(910 [ECYT]), 	shares: 39215, 	price: 4.25
# Buying Equity(935 [ELGX]), 	shares: 33003, 	price: 5.05
# Buying Equity(961 [ENZ]), 	shares: 20202, 	price: 8.25
# Buying Equity(1062 [FDUS]), 	shares: 11185, 	price: 14.9
# Buying Equity(1068 [FF]), 	shares: 12077, 	price: 13.8
# Buying Equity(1131 [FRBK]), 	shares: 19723, 	price: 8.45
# Buying Equity(1141 [FRSH]), 	shares: 30030, 	price: 5.55
# Buying Equity(1153 [FTD]), 	shares: 21786, 	price: 7.65
# Buying Equity(1173 [GAIA]), 	shares: 13947, 	price: 11.95
# Buying Equity(1177 [GARS]), 	shares: 20703, 	price: 8.05
# Buying Equity(1196 [GEOS]), 	shares: 11614, 	price: 14.35
# Buying Equity(1215 [GLAD]), 	shares: 18214, 	price: 9.15
# Buying Equity(1236 [GNE]), 	shares: 37453, 	price: 4.45
# Buying Equity(1237 [GNMK]), 	shares: 33670, 	price: 4.95
# Buying Equity(1282 [GTXI]), 	shares: 15220, 	price: 10.95
#                            LowestPrice  algo_volatility  \
# 2018-01-02 21:00:00+00:00          3.0              NaN
# 2018-01-03 21:00:00+00:00          3.0              0.0
# 2018-01-04 21:00:00+00:00          3.0              0.0
# 2018-01-05 21:00:00+00:00          3.0              0.0
#
#                            algorithm_period_return  alpha  \
# 2018-01-02 21:00:00+00:00                      0.0    NaN
# 2018-01-03 21:00:00+00:00                      0.0    0.0
# 2018-01-04 21:00:00+00:00                      0.0    0.0
# 2018-01-05 21:00:00+00:00                      0.0    0.0
#
#                            benchmark_period_return  benchmark_volatility  \
# 2018-01-02 21:00:00+00:00                 0.007157                   NaN
# 2018-01-03 21:00:00+00:00                 0.013528              0.009338
# 2018-01-04 21:00:00+00:00                 0.017800              0.024077
# 2018-01-05 21:00:00+00:00                 0.024582              0.020574
#
#                            beta  capital_used  ending_cash  ending_exposure  \
# 2018-01-02 21:00:00+00:00   NaN           0.0   10000000.0              0.0
# 2018-01-03 21:00:00+00:00   0.0           0.0   10000000.0              0.0
# 2018-01-04 21:00:00+00:00   0.0           0.0   10000000.0              0.0
# 2018-01-05 21:00:00+00:00   0.0           0.0   10000000.0              0.0
#
#                                     ...            short_exposure  \
# 2018-01-02 21:00:00+00:00           ...                       0.0
# 2018-01-03 21:00:00+00:00           ...                       0.0
# 2018-01-04 21:00:00+00:00           ...                       0.0
# 2018-01-05 21:00:00+00:00           ...                       0.0
#
#                            short_value  shorts_count  sortino  starting_cash  \
# 2018-01-02 21:00:00+00:00          0.0             0     None     10000000.0
# 2018-01-03 21:00:00+00:00          0.0             0     None     10000000.0
# 2018-01-04 21:00:00+00:00          0.0             0     None     10000000.0
# 2018-01-05 21:00:00+00:00          0.0             0     None     10000000.0
#
#                            starting_exposure  starting_value  trading_days  \
# 2018-01-02 21:00:00+00:00                0.0             0.0             1
# 2018-01-03 21:00:00+00:00                0.0             0.0             2
# 2018-01-04 21:00:00+00:00                0.0             0.0             3
# 2018-01-05 21:00:00+00:00                0.0             0.0             4
#
#                            transactions  treasury_period_return
# 2018-01-02 21:00:00+00:00            []                     0.0
# 2018-01-03 21:00:00+00:00            []                     0.0
# 2018-01-04 21:00:00+00:00            []                     0.0
# 2018-01-05 21:00:00+00:00            []                     0.0
#
# [4 rows x 39 columns]

# %%
start_date = pd.to_datetime('2018-01-01').tz_localize('UTC')
end_date = pd.to_datetime('2018-01-03').tz_localize('UTC')
run_algorithm(start=start_date, 
              end=end_date, 
              initialize=initialize, 
              capital_base=25000, 
              handle_data=handle_data,
              before_trading_start = before_trading_start)
# Out:
# 0
#
# Algorithm initialized variables:
#  context.MaxCandidates 100
#  LowVar 6
#  HighVar 40
# > <ipython-input-18-3965b038a3f8>(96)make_pipeline()
#      95
# ---> 96     return Pipeline(
#      97         columns={
#
# ipdb> c
# /anaconda3/envs/env_zipline/lib/python3.5/site-packages/zipline/pipeline/filters/filter.py:382: RuntimeWarning: invalid value encountered in less_equal
#   return (lower_bounds <= data) & (data <= upper_bounds)
# stocks_worst: [Equity(40 [ACRE]), Equity(42 [ACTG]), Equity(47 [ADES]), Equity(88 [AGTC]), Equity(161 [AMSWA]), Equity(190 [AOSL]), Equity(191 [AP]), Equity(232 [ASC]), Equity(271 [AVHI]), Equity(275 [AVNW]), Equity(278 [AVX]), Equity(327 [BCOV]), Equity(348 [BFIN]), Equity(414 [BPI]), Equity(520 [CCXI]), Equity(527 [CECE]), Equity(534 [CERS]), Equity(556 [CHFN]), Equity(570 [CIA]), Equity(591 [CLFD]), Equity(599 [CLUB]), Equity(637 [COBZ]), Equity(721 [CSWC]), Equity(786 [DAKT]), Equity(818 [DGII]), Equity(823 [DHT]), Equity(867 [DSPG]), Equity(910 [ECYT]), Equity(935 [ELGX]), Equity(961 [ENZ]), Equity(1029 [EXXI]), Equity(1062 [FDUS]), Equity(1068 [FF]), Equity(1131 [FRBK]), Equity(1141 [FRSH]), Equity(1153 [FTD]), Equity(1177 [GARS]), Equity(1196 [GEOS]), Equity(1215 [GLAD]), Equity(1236 [GNE]), Equity(1237 [GNMK]), Equity(1273 [GSVC]), Equity(1377 [HOS]), Equ
# Buying Equity(2457 [RRTS]), 	shares: 53, 	price: 7.8
# Buying Equity(2462 [RSO]), 	shares: 45, 	price: 9.25
# Buying Equity(2470 [RTIX]), 	shares: 102, 	price: 4.05
# Buying Equity(2478 [RVLT]), 	shares: 130, 	price: 3.2
# Buying Equity(2492 [SALM]), 	shares: 98, 	price: 4.25
# Buying Equity(2501 [SB]), 	shares: 128, 	price: 3.25
# Buying Equity(2542 [SFE]), 	shares: 37, 	price: 11.05
# Buying Equity(2563 [SHLO]), 	shares: 49, 	price: 8.4
# Buying Equity(2637 [SPNS]), 	shares: 35, 	price: 11.9
# Buying Equity(2697 [SUNS]), 	shares: 23, 	price: 17.45
# Buying Equity(2698 [SUP]), 	shares: 28, 	price: 14.85
# Buying Equity(2743 [TAX]), 	shares: 38, 	price: 10.85
# Buying Equity(2756 [TCRD]), 	shares: 45, 	price: 9.15
# Buying Equity(2757 [TCS]), 	shares: 83, 	price: 5.0
# Buying Equity(2796 [TICC]), 	shares: 71, 	price: 5.85
# Buying Equity(2801 [TIS]), 	shares: 32, 	price: 12.9
# Buying Equity(2843 [TRK]), 	shares: 22, 	price: 18.9
# Buying Equity(2911 [UBNK]), 	shares: 24, 	price: 17.2
# Buying Equity(2916 [UCFC]), 	shares: 46, 	price: 9.05
# Buying Equity(2986 [VCYT]), 	shares: 62, 	price: 6.65
# Buying Equity(2992 [VHC]), 	shares: 111, 	price: 3.75
# Buying Equity(3014 [VOXX]), 	shares: 75, 	price: 5.5
# Buying Equity(3083 [WHF]), 	shares: 32, 	price: 13.0
# Buying Equity(3120 [WSBF]), 	shares: 24, 	price: 16.95
# Buying Equity(3159 [XONE]), 	shares: 47, 	price: 8.75
# Buying Equity(3161 [XOXO]), 	shares: 22, 	price: 18.3
# Buying Equity(3190 [ZIXI]), 	shares: 94, 	price: 4.4
# Buying Equity(40 [ACRE]), 	shares: 32, 	price: 12.65
# Buying Equity(42 [ACTG]), 	shares: 105, 	price: 3.95
# Buying Equity(47 [ADES]), 	shares: 44, 	price: 9.4
# Buying Equity(88 [AGTC]), 	shares: 112, 	price: 3.7
# Buying Equity(161 [AMSWA]), 	shares: 35, 	price: 11.65
# Buying Equity(190 [AOSL]), 	shares: 25, 	price: 16.65
# Buying Equity(191 [AP]), 	shares: 32, 	price: 12.75
# Buying Equity(232 [ASC]), 	shares: 52, 	price: 8.0
# Buying Equity(271 [AVHI]), 	shares: 24, 	price: 17.35
# Buying Equity(275 [AVNW]), 	shares: 27, 	price: 14.95
# Buying Equity(278 [AVX]), 	shares: 24, 	price: 17.35
# Buying Equity(327 [BCOV]), 	shares: 59, 	price: 7.0
# Buying Equity(348 [BFIN]), 	shares: 27, 	price: 15.15
# Buying Equity(414 [BPI]), 	shares: 51, 	price: 8.05
# Buying Equity(520 [CCXI]), 	shares: 71, 	price: 5.8
# Buying Equity(527 [CECE]), 	shares: 80, 	price: 5.15
# Buying Equity(534 [CERS]), 	shares: 119, 	price: 3.5
# Buying Equity(556 [CHFN]), 	shares: 24, 	price: 17.15
# Buying Equity(570 [CIA]), 	shares: 56, 	price: 7.4
# Buying Equity(591 [CLFD]), 	shares: 35, 	price: 11.9
# Buying Equity(599 [CLUB]), 	shares: 77, 	price: 5.4
# Buying Equity(637 [COBZ]), 	shares: 21, 	price: 19.55
# Buying Equity(721 [CSWC]), 	shares: 24, 	price: 16.7
# Buying Equity(786 [DAKT]), 	shares: 46, 	price: 9.05
# Buying Equity(818 [DGII]), 	shares: 42, 	price: 9.8
# Buying Equity(823 [DHT]), 	shares: 114, 	price: 3.65
# Buying Equity(867 [DSPG]), 	shares: 34, 	price: 12.15
# Buying Equity(910 [ECYT]), 	shares: 92, 	price: 4.5
# Buying Equity(935 [ELGX]), 	shares: 81, 	price: 5.1
# Buying Equity(961 [ENZ]), 	shares: 51, 	price: 8.15
# Buying Equity(1029 [EXXI]), 	shares: 68, 	price: 6.05
# Buying Equity(1062 [FDUS]), 	shares: 27, 	price: 15.35
# Buying Equity(1068 [FF]), 	shares: 29, 	price: 13.9
# Buying Equity(1131 [FRBK]), 	shares: 49, 	price: 8.5
# Buying Equity(1141 [FRSH]), 	shares: 73, 	price: 5.65
# Buying Equity(1153 [FTD]), 	shares: 56, 	price: 7.4
# Buying Equity(1177 [GARS]), 	shares: 51, 	price: 8.05
# Buying Equity(1196 [GEOS]), 	shares: 31, 	price: 13.35
# Buying Equity(1215 [GLAD]), 	shares: 45, 	price: 9.15
# Buying Equity(1236 [GNE]), 	shares: 91, 	price: 4.55
# Buying Equity(1237 [GNMK]), 	shares: 90, 	price: 4.6
# Buying Equity(1273 [GSVC]), 	shares: 75, 	price: 5.5
# Buying Equity(1377 [HOS]), 	shares: 138, 	price: 3.0
# Buying Equity(1434 [I]), 	shares: 115, 	price: 3.6
# Buying Equity(1544 [IVAC]), 	shares: 64, 	price: 6.5
# Buying Equity(1567 [JMBA]), 	shares: 52, 	price: 7.9
# Buying Equity(1616 [KODK]), 	shares: 134, 	price: 3.1
# Buying Equity(1622 [KPTI]), 	shares: 42, 	price: 9.8
# Buying Equity(1646 [LAYN]), 	shares: 32, 	price: 12.65
# Buying Equity(1649 [LBAI]), 	shares: 21, 	price: 19.05
# Buying Equity(1655 [LCUT]), 	shares: 24, 	price: 16.8
# Buying Equity(1700 [LNDC]), 	shares: 33, 	price: 12.35
# ...
# Buying Equity(2542 [SFE]), 	shares: 37, 	price: 11.0
# Buying Equity(2563 [SHLO]), 	shares: 49, 	price: 8.4
# Buying Equity(2637 [SPNS]), 	shares: 34, 	price: 12.1
# Buying Equity(2698 [SUP]), 	shares: 27, 	price: 15.3
# Buying Equity(2743 [TAX]), 	shares: 36, 	price: 11.3
# Buying Equity(2756 [TCRD]), 	shares: 46, 	price: 9.05
# Buying Equity(2757 [TCS]), 	shares: 86, 	price: 4.8
# Buying Equity(2796 [TICC]), 	shares: 73, 	price: 5.7
# Buying Equity(2801 [TIS]), 	shares: 32, 	price: 12.8
# Buying Equity(2843 [TRK]), 	shares: 22, 	price: 18.75
# Buying Equity(2911 [UBNK]), 	shares: 24, 	price: 16.95
# Buying Equity(2916 [UCFC]), 	shares: 45, 	price: 9.2
# Buying Equity(2986 [VCYT]), 	shares: 63, 	price: 6.6
# Buying Equity(2992 [VHC]), 	shares: 111, 	price: 3.75
# Buying Equity(3014 [VOXX]), 	shares: 75, 	price: 5.55
# Buying Equity(3083 [WHF]), 	shares: 31, 	price: 13.2
# Buying Equity(3120 [WSBF]), 	shares: 24, 	price: 16.75
# Buying Equity(3159 [XONE]), 	shares: 46, 	price: 8.95
# Buying Equity(3161 [XOXO]), 	shares: 21, 	price: 19.0
# Buying Equity(3190 [ZIXI]), 	shares: 95, 	price: 4.35
# Buying Equity(40 [ACRE]), 	shares: 33, 	price: 12.4
# Buying Equity(42 [ACTG]), 	shares: 111, 	price: 3.75
# Buying Equity(47 [ADES]), 	shares: 44, 	price: 9.3
# Buying Equity(161 [AMSWA]), 	shares: 35, 	price: 11.85
# Buying Equity(190 [AOSL]), 	shares: 24, 	price: 17.25
# Buying Equity(191 [AP]), 	shares: 33, 	price: 12.45
# Buying Equity(232 [ASC]), 	shares: 51, 	price: 8.15
# Buying Equity(271 [AVHI]), 	shares: 23, 	price: 18.0
# Buying Equity(275 [AVNW]), 	shares: 27, 	price: 15.15
# Buying Equity(327 [BCOV]), 	shares: 58, 	price: 7.1
# Buying Equity(348 [BFIN]), 	shares: 27, 	price: 15.35
# Buying Equity(414 [BPI]), 	shares: 52, 	price: 7.9
# Buying Equity(471 [CALX]), 	shares: 73, 	price: 5.65
# Buying Equity(520 [CCXI]), 	shares: 68, 	price: 6.1
# Buying Equity(527 [CECE]), 	shares: 82, 	price: 5.05
# Buying Equity(534 [CERS]), 	shares: 117, 	price: 3.55
# Buying Equity(556 [CHFN]), 	shares: 23, 	price: 17.4
# Buying Equity(570 [CIA]), 	shares: 55, 	price: 7.45
# Buying Equity(591 [CLFD]), 	shares: 34, 	price: 12.1
# Buying Equity(599 [CLUB]), 	shares: 75, 	price: 5.5
# Buying Equity(637 [COBZ]), 	shares: 21, 	price: 19.65
# Buying Equity(714 [CSLT]), 	shares: 109, 	price: 3.8
# Buying Equity(721 [CSWC]), 	shares: 25, 	price: 16.5
# Buying Equity(786 [DAKT]), 	shares: 46, 	price: 9.05
# Buying Equity(818 [DGII]), 	shares: 40, 	price: 10.4
# Buying Equity(823 [DHT]), 	shares: 111, 	price: 3.75
# Buying Equity(867 [DSPG]), 	shares: 31, 	price: 13.1
# Buying Equity(910 [ECYT]), 	shares: 94, 	price: 4.4
# Buying Equity(961 [ENZ]), 	shares: 51, 	price: 8.05
# Buying Equity(970 [EPM]), 	shares: 59, 	price: 6.95
# Buying Equity(1029 [EXXI]), 	shares: 65, 	price: 6.35
# Buying Equity(1062 [FDUS]), 	shares: 27, 	price: 15.3
# Buying Equity(1068 [FF]), 	shares: 30, 	price: 13.45
# Buying Equity(1131 [FRBK]), 	shares: 49, 	price: 8.4
# Buying Equity(1141 [FRSH]), 	shares: 75, 	price: 5.55
# Buying Equity(1153 [FTD]), 	shares: 56, 	price: 7.4
# Buying Equity(1177 [GARS]), 	shares: 51, 	price: 8.1
# Buying Equity(1196 [GEOS]), 	shares: 30, 	price: 13.5
# Buying Equity(1200 [GFF]), 	shares: 21, 	price: 19.8
# Buying Equity(1215 [GLAD]), 	shares: 45, 	price: 9.25
# Buying Equity(1236 [GNE]), 	shares: 95, 	price: 4.35
# Buying Equity(1237 [GNMK]), 	shares: 89, 	price: 4.65
# Buying Equity(1273 [GSVC]), 	shares: 68, 	price: 6.1
# Buying Equity(1297 [HALL]), 	shares: 41, 	price: 10.0
# Buying Equity(1377 [HOS]), 	shares: 114, 	price: 3.65
# Buying Equity(1434 [I]), 	shares: 115, 	price: 3.6
# Buying Equity(1544 [IVAC]), 	shares: 65, 	price: 6.4
# Buying Equity(1567 [JMBA]), 	shares: 50, 	price: 8.2
# Buying Equity(1603 [KIRK]), 	shares: 36, 	price: 11.55
# Buying Equity(1616 [KODK]), 	shares: 138, 	price: 3.0
# Buying Equity(1622 [KPTI]), 	shares: 41, 	price: 9.95
# Buying Equity(1649 [LBAI]), 	shares: 21, 	price: 19.0
# Buying Equity(1655 [LCUT]), 	shares: 24, 	price: 17.0
# Buying Equity(1719 [LQDT]), 	shares: 89, 	price: 4.65
# Buying Equity(1749 [MACK]), 	shares: 38, 	price: 10.75
# Buying Equity(1769 [MCC]), 	shares: 80, 	price: 5.15
# Buying Equity(1850 [MN]), 	shares: 114, 	price: 3.65
# Buying Equity(1876 [MPX]), 	shares: 32, 	price: 12.9
# Buying Equity(1919 [MVC]), 	shares: 39, 	price: 10.45
# Buying Equity(1930 [MYE]), 	shares: 20, 	price: 20.35
# Buying Equity(1968 [NEO]), 	shares: 49, 	price: 8.45
# Buying Equity(2031 [NSTG]), 	shares: 54, 	price: 7.7
# Buying Equity(2103 [OMED]), 	shares: 108, 	price: 3.85
# Buying Equity(2108 [OMN]), 	shares: 41, 	price: 10.05
# Buying Equity(2129 [ORM]), 	shares: 27, 	price: 14.95
# Buying Equity(2178 [PCYG]), 	shares: 44, 	price: 9.35
# Buying Equity(2201 [PETX]), 	shares: 80, 	price: 5.2
# Buying Equity(2222 [PHIIK]), 	shares: 35, 	price: 11.9
# Buying Equity(2226 [PICO]), 	shares: 33, 	price: 12.35
# Buying Equity(2282 [PPHM]), 	shares: 102, 	price: 4.05
# Buying Equity(2333 [PZN]), 	shares: 41, 	price: 10.15
# Buying Equity(2379 [RECN]), 	shares: 27, 	price: 15.05
# Buying Equity(2428 [RMTI]), 	shares: 73, 	price: 5.7
# Buying Equity(2430 [RNET]), 	shares: 25, 	price: 16.2
# Buying Equity(2434 [RNWK]), 	shares: 126, 	price: 3.3
# Buying Equity(2457 [RRTS]), 	shares: 53, 	price: 7.75
# Buying Equity(2462 [RSO]), 	shares: 45, 	price: 9.15
# Buying Equity(2470 [RTIX]), 	shares: 100, 	price: 4.15
# Buying Equity(2478 [RVLT]), 	shares: 136, 	price: 3.05
# Buying Equity(2492 [SALM]), 	shares: 101, 	price: 4.1
# Buying Equity(2542 [SFE]), 	shares: 37, 	price: 11.0
# Buying Equity(2563 [SHLO]), 	shares: 49, 	price: 8.4
# Buying Equity(2637 [SPNS]), 	shares: 34, 	price: 12.1
# Buying Equity(2698 [SUP]), 	shares: 27, 	price: 15.3
# Buying Equity(2743 [TAX]), 	shares: 36, 	price: 11.3
# Buying Equity(2756 [TCRD]), 	shares: 46, 	price: 9.05
# Buying Equity(2757 [TCS]), 	shares: 86, 	price: 4.8
# Buying Equity(2796 [TICC]), 	shares: 73, 	price: 5.7
# Buying Equity(2801 [TIS]), 	shares: 32, 	price: 12.8
# Buying Equity(2843 [TRK]), 	shares: 22, 	price: 18.75
# Buying Equity(2911 [UBNK]), 	shares: 24, 	price: 16.95
# Buying Equity(2916 [UCFC]), 	shares: 45, 	price: 9.2
# Buying Equity(2986 [VCYT]), 	shares: 63, 	price: 6.6
# Buying Equity(2992 [VHC]), 	shares: 111, 	price: 3.75
# Buying Equity(3014 [VOXX]), 	shares: 75, 	price: 5.55
# Buying Equity(3083 [WHF]), 	shares: 31, 	price: 13.2
# Buying Equity(3120 [WSBF]), 	shares: 24, 	price: 16.75
# Buying Equity(3159 [XONE]), 	shares: 46, 	price: 8.95
# Buying Equity(3161 [XOXO]), 	shares: 21, 	price: 19.0
# Buying Equity(3190 [ZIXI]), 	shares: 95, 	price: 4.35
# Buying Equity(40 [ACRE]), 	shares: 33, 	price: 12.4
# Buying Equity(42 [ACTG]), 	shares: 111, 	price: 3.75
# Buying Equity(47 [ADES]), 	shares: 44, 	price: 9.3
# Buying Equity(161 [AMSWA]), 	shares: 35, 	price: 11.85
# Buying Equity(190 [AOSL]), 	shares: 24, 	price: 17.25
# Buying Equity(191 [AP]), 	shares: 33, 	price: 12.45
# Buying Equity(232 [ASC]), 	shares: 51, 	price: 8.15
# Buying Equity(271 [AVHI]), 	shares: 23, 	price: 18.0
# Buying Equity(275 [AVNW]), 	shares: 27, 	price: 15.15
# Buying Equity(327 [BCOV]), 	shares: 58, 	price: 7.1
# Buying Equity(348 [BFIN]), 	shares: 27, 	price: 15.35
# Buying Equity(414 [BPI]), 	shares: 52, 	price: 7.9
# Buying Equity(471 [CALX]), 	shares: 73, 	price: 5.65
# Buying Equity(520 [CCXI]), 	shares: 68, 	price: 6.1
# Buying Equity(527 [CECE]), 	shares: 82, 	price: 5.05
# Buying Equity(534 [CERS]), 	shares: 117, 	price: 3.55
# Buying Equity(556 [CHFN]), 	shares: 23, 	price: 17.4
# Buying Equity(570 [CIA]), 	shares: 55, 	price: 7.45
# Buying Equity(591 [CLFD]), 	shares: 34, 	price: 12.1
# Buying Equity(599 [CLUB]), 	shares: 75, 	price: 5.5
# Buying Equity(637 [COBZ]), 	shares: 21, 	price: 19.65
# Buying Equity(714 [CSLT]), 	shares: 109, 	price: 3.8
# Buying Equity(721 [CSWC]), 	shares: 25, 	price: 16.5
# Buying Equity(786 [DAKT]), 	shares: 46, 	price: 9.05
# Buying Equity(818 [DGII]), 	shares: 40, 	price: 10.4
# Buying Equity(823 [DHT]), 	shares: 111, 	price: 3.75
# Buying Equity(867 [DSPG]), 	shares: 31, 	price: 13.1
# Buying Equity(910 [ECYT]), 	shares: 94, 	price: 4.4
# Buying Equity(961 [ENZ]), 	shares: 51, 	price: 8.05
# Buying Equity(970 [EPM]), 	shares: 59, 	price: 6.95
# Buying Equity(1029 [EXXI]), 	shares: 65, 	price: 6.35
# Buying Equity(1062 [FDUS]), 	shares: 27, 	price: 15.3
# Buying Equity(1068 [FF]), 	shares: 30, 	price: 13.45
# Buying Equity(1131 [FRBK]), 	shares: 49, 	price: 8.4
# Buying Equity(1141 [FRSH]), 	shares: 75, 	price: 5.55
# Buying Equity(1153 [FTD]), 	shares: 56, 	price: 7.4
# Buying Equity(1177 [GARS]), 	shares: 51, 	price: 8.1
# Buying Equity(1196 [GEOS]), 	shares: 30, 	price: 13.5
# Buying Equity(1200 [GFF]), 	shares: 21, 	price: 19.8
# Buying Equity(1215 [GLAD]), 	shares: 45, 	price: 9.25
# Buying Equity(1236 [GNE]), 	shares: 95, 	price: 4.35
# Buying Equity(1237 [GNMK]), 	shares: 89, 	price: 4.65
# Buying Equity(1273 [GSVC]), 	shares: 68, 	price: 6.1
# Buying Equity(1297 [HALL]), 	shares: 41, 	price: 10.0
# Buying Equity(1377 [HOS]), 	shares: 114, 	price: 3.65
# Buying Equity(1434 [I]), 	shares: 115, 	price: 3.6
# Buying Equity(1544 [IVAC]), 	shares: 65, 	price: 6.4
# Buying Equity(1567 [JMBA]), 	shares: 50, 	price: 8.2
# Buying Equity(1603 [KIRK]), 	shares: 36, 	price: 11.55
# Buying Equity(1616 [KODK]), 	shares: 138, 	price: 3.0
# Buying Equity(1622 [KPTI]), 	shares: 41, 	price: 9.95
# Buying Equity(1649 [LBAI]), 	shares: 21, 	price: 19.0
# Buying Equity(1655 [LCUT]), 	shares: 24, 	price: 17.0
# Buying Equity(1719 [LQDT]), 	shares: 89, 	price: 4.65
# Buying Equity(1749 [MACK]), 	shares: 38, 	price: 10.75
# Buying Equity(1769 [MCC]), 	shares: 80, 	price: 5.15
# Buying Equity(1850 [MN]), 	shares: 114, 	price: 3.65
# Buying Equity(47 [ADES]), 	shares: 44, 	price: 9.3
# Buying Equity(161 [AMSWA]), 	shares: 35, 	price: 11.85
# Buying Equity(190 [AOSL]), 	shares: 24, 	price: 17.25
# Buying Equity(191 [AP]), 	shares: 33, 	price: 12.45
# Buying Equity(232 [ASC]), 	shares: 51, 	price: 8.15
# Buying Equity(271 [AVHI]), 	shares: 23, 	price: 18.0
# Buying Equity(275 [AVNW]), 	shares: 27, 	price: 15.15
# Buying Equity(327 [BCOV]), 	shares: 58, 	price: 7.1
# Buying Equity(348 [BFIN]), 	shares: 27, 	price: 15.35
# Buying Equity(414 [BPI]), 	shares: 52, 	price: 7.9
# Buying Equity(471 [CALX]), 	shares: 73, 	price: 5.65
# Buying Equity(520 [CCXI]), 	shares: 68, 	price: 6.1
# Buying Equity(527 [CECE]), 	shares: 82, 	price: 5.05
# Buying Equity(534 [CERS]), 	shares: 117, 	price: 3.55
# Buying Equity(556 [CHFN]), 	shares: 23, 	price: 17.4
# Buying Equity(570 [CIA]), 	shares: 55, 	price: 7.45
# Buying Equity(591 [CLFD]), 	shares: 34, 	price: 12.1
# Buying Equity(599 [CLUB]), 	shares: 75, 	price: 5.5
# Buying Equity(637 [COBZ]), 	shares: 21, 	price: 19.65
# Buying Equity(714 [CSLT]), 	shares: 109, 	price: 3.8
# Buying Equity(721 [CSWC]), 	shares: 25, 	price: 16.5
# Buying Equity(786 [DAKT]), 	shares: 46, 	price: 9.05
# Buying Equity(818 [DGII]), 	shares: 40, 	price: 10.4
# Buying Equity(823 [DHT]), 	shares: 111, 	price: 3.75
# Buying Equity(867 [DSPG]), 	shares: 31, 	price: 13.1
# Buying Equity(910 [ECYT]), 	shares: 94, 	price: 4.4
# Buying Equity(961 [ENZ]), 	shares: 51, 	price: 8.05
# Buying Equity(970 [EPM]), 	shares: 59, 	price: 6.95
# Buying Equity(1029 [EXXI]), 	shares: 65, 	price: 6.35
# Buying Equity(1062 [FDUS]), 	shares: 27, 	price: 15.3
# Buying Equity(1068 [FF]), 	shares: 30, 	price: 13.45
# Buying Equity(1131 [FRBK]), 	shares: 49, 	price: 8.4
# Buying Equity(1141 [FRSH]), 	shares: 75, 	price: 5.55
# Buying Equity(1153 [FTD]), 	shares: 56, 	price: 7.4
# Buying Equity(1177 [GARS]), 	shares: 51, 	price: 8.1
# Buying Equity(1196 [GEOS]), 	shares: 30, 	price: 13.5
# Buying Equity(1200 [GFF]), 	shares: 21, 	price: 19.8
# Buying Equity(1215 [GLAD]), 	shares: 45, 	price: 9.25
# /anaconda3/envs/env_zipline/lib/python3.5/site-packages/empyrical/stats.py:704: RuntimeWarning: invalid value encountered in true_divide
#   out=out,
# /anaconda3/envs/env_zipline/lib/python3.5/site-packages/empyrical/stats.py:790: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
#                            LowestPrice  algo_volatility  \
# 2018-01-02 21:00:00+00:00          3.0              NaN
# 2018-01-03 21:00:00+00:00          3.0              0.0
#
#                            algorithm_period_return  alpha  \
# 2018-01-02 21:00:00+00:00                      0.0    NaN
# 2018-01-03 21:00:00+00:00                      0.0    0.0
#
#                            benchmark_period_return  benchmark_volatility  \
# 2018-01-02 21:00:00+00:00                 0.007157                   NaN
# 2018-01-03 21:00:00+00:00                 0.013528              0.009338
#
#                            beta  capital_used  ending_cash  ending_exposure  \
# 2018-01-02 21:00:00+00:00   NaN           0.0      25000.0              0.0
# 2018-01-03 21:00:00+00:00   0.0           0.0      25000.0              0.0
#
#                                     ...            short_exposure  \
# 2018-01-02 21:00:00+00:00           ...                       0.0
# 2018-01-03 21:00:00+00:00           ...                       0.0
#
#                            short_value  shorts_count  sortino  starting_cash  \
# 2018-01-02 21:00:00+00:00          0.0             0     None        25000.0
# 2018-01-03 21:00:00+00:00          0.0             0     None        25000.0
#
#                            starting_exposure  starting_value  trading_days  \
# 2018-01-02 21:00:00+00:00                0.0             0.0             1
# 2018-01-03 21:00:00+00:00                0.0             0.0             2
#
#                            transactions  treasury_period_return
# 2018-01-02 21:00:00+00:00            []                     0.0
# 2018-01-03 21:00:00+00:00            []                     0.0
#
# [2 rows x 39 columns]

# %%
# %whos
# Out:
# Variable                 Type           Data/Info
# -------------------------------------------------
# AverageDollarVolume      ABCMeta        <class 'zipline.pipeline.<...>sic.AverageDollarVolume'>
# LimitOrder               ABCMeta        <class 'zipline.finance.execution.LimitOrder'>
# Pipeline                 type           <class 'zipline.pipeline.pipeline.Pipeline'>
# SimpleMovingAverage      ABCMeta        <class 'zipline.pipeline.<...>sic.SimpleMovingAverage'>
# USEquityPricing          DataSetMeta    <DataSet: 'USEquityPricing'>
# before_trading_start     function       <function before_trading_start at 0x1a202a1a60>
# cancel_open_buy_orders   function       <function cancel_open_buy_orders at 0x1a202bc400>
# cancel_open_orders       function       <function cancel_open_orders at 0x1a202bc598>
# commission               module         <module 'zipline.finance.<...>e/finance/commission.py'>
# cycle                    type           <class 'itertools.cycle'>
# handle_data              function       <function handle_data at 0x1a202bc488>
# initialize               function       <function initialize at 0x1a202a1950>
# log_open_order           function       <function log_open_order at 0x1a202bc378>
# log_open_orders          function       <function log_open_orders at 0x1a202bc158>
# make_div_by_05           function       <function make_div_by_05 at 0x1a202a1e18>
# make_pipeline            function       <function make_pipeline at 0x1a202a1b70>
# math                     module         <module 'math' from '/ana<...>h.cpython-35m-darwin.so'>
# my_compute_weights       function       <function my_compute_weights at 0x1a202a1620>
# my_rebalance             function       <function my_rebalance at 0x1a202a18c8>
# my_record_vars           function       <function my_record_vars at 0x1a202bc1e0>
# np                       module         <module 'numpy' from '/an<...>kages/numpy/__init__.py'>
# order                    function       <function TradingAlgorithm.order at 0x1a20293378>
# record                   function       <function TradingAlgorith<...>m.record at 0x1a2029bbf8>
# slippage                 module         <module 'zipline.finance.<...>ine/finance/slippage.py'>
# symbol                   function       <function TradingAlgorith<...>m.symbol at 0x1a2029bd90>
# za                       module         <module 'zipline.api' fro<...>packages/zipline/api.py'>
